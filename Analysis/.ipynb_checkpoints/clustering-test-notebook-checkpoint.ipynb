# %%
import pandas as pd
import numpy as np
import itertools
import sklearn.cluster as skc
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from mpl_toolkits.mplot3d import Axes3D
import plotly.plotly as py
import plotly.tools as tls
py.sign_in('AbhishekMalali', 'rwqa8v03mr')
from plotly.graph_objs import *
# %matplotlib inline

# %% [markdown]
# #### Loading the data for the 2012-13 Season

# %%
features12 = pd.read_pickle('../Data/features12-13.pkl')
tr_features12 = features12.transpose()

# %%
#Splitting the smoothed_value_list into 38 new columns
split_fn = lambda x: pd.Series([i for i in x])
tr_features12_sm = tr_features12['smoothed_value_list'].apply(split_fn)

# %%
#Splitting the cum_value_list into 38 new columns
tr_features12_cm = tr_features12['cum_value_list'].apply(split_fn)

# %%
#Generating column names for the new dataframe
col_names_sm = []
col_names_cm = []
for i in range(38):
    col_names_sm.append('smooth_value_week_'+str(i+1))
    col_names_cm.append('cuml_value_week_'+str(i+1))

# %%
#Setting the column names for the new dataframe
tr_features12_sm.columns = col_names_sm
tr_features12_cm.columns = col_names_cm

# %%
#Concatenating the two dataframes
df_features12 = pd.concat([tr_features12,tr_features12_sm,tr_features12_cm],axis=1)

# %%
#Selecting columns to be clustered
columns_cluster = [[u'avg_value'], [u'avg_value_smoothed'],
        [u'nassists'], [u'naway_assists'], [u'naway_goals'],
        [u'nearly_assists'], [u'nearly_goals'], [u'nequalizer_assists'],
        [u'nequalizer_goals'], [u'ngoals'], [u'nhome_assists'], [u'nhome_goals'],
        [u'nlate_assists'], [u'nlate_goals'], [u'nmid_assists'], [u'nmid_goals'],
        [u'nsub_assists'], [u'nsub_goals'], [u'ntiebreaker_assists'],
        [u'ntiebreaker_goals'], [u'season_value'],col_names_sm, col_names_cm]
columns_cluster = list(itertools.chain(*columns_cluster))

# %%
#Creating a new dataframe to be used for clustering
df_clustering = df_features12[columns_cluster]

# %%
df_clustering.head()
# Out:
#                     avg_value avg_value_smoothed nassists naway_assists  \
# Aaron Hunt           1.142434            1.19568        4             0
# Aaron Lennon        0.6901316          0.5942928        7             2
# Aaron Ramsey        0.1848684          0.1690789        2             2
# Abdelaziz Barrada   0.7023026          0.7875164        6             1
# Abdou TraorÃ©      0.01973684        0.003947368        1             0
#
#                   naway_goals nearly_assists nearly_goals nequalizer_assists  \
# Aaron Hunt                  5              0            3                  0
# Aaron Lennon                1              1            1                  1
# Aaron Ramsey                0              1            0                  0
# Abdelaziz Barrada           2              1            0                  1
# Abdou TraorÃ©               0              0            0                  0
#
#                   nequalizer_goals ngoals        ...          \
# Aaron Hunt                       2     11        ...
# Aaron Lennon                     0      4        ...
# Aaron Ramsey                     0      1        ...
# Abdelaziz Barrada                2      4        ...
# Abdou TraorÃ©                    0      0        ...
#
#                   cuml_value_week_29 cuml_value_week_30 cuml_value_week_31  \
# Aaron Hunt                   40.4125            40.4125            40.4125
# Aaron Lennon                 21.4750            21.4750            21.4750
# Aaron Ramsey                  3.1625             6.0250             6.0250
# Abdelaziz Barrada            23.6875            23.6875            23.6875
# Abdou TraorÃ©                 0.0000             0.0000             0.0000
#
#                   cuml_value_week_32 cuml_value_week_33 cuml_value_week_34  \
# Aaron Hunt                   43.4125            43.4125            43.4125
# Aaron Lennon                 21.4750            21.4750            21.4750
# Aaron Ramsey                  6.0250             6.0250             6.0250
# Abdelaziz Barrada            23.6875            23.6875            26.6875
# Abdou TraorÃ©                 0.0000             0.0000             0.0000
#
#                   cuml_value_week_35 cuml_value_week_36 cuml_value_week_37  \
# Aaron Hunt                   43.4125            43.4125            43.4125
# Aaron Lennon                 21.4750            21.4750            21.4750
# Aaron Ramsey                  6.0250             6.0250             7.0250
# Abdelaziz Barrada            26.6875            26.6875            26.6875
# Abdou TraorÃ©                 0.0000             0.0000             0.0000
#
#                   cuml_value_week_38
# Aaron Hunt                   43.4125
# Aaron Lennon                 26.2250
# Aaron Ramsey                  7.0250
# Abdelaziz Barrada            26.6875
# Abdou TraorÃ©                 0.7500
#
# [5 rows x 97 columns]

# %% [markdown]
# #### Clustering the data using K-Means

# %%
n_clusters = 10
km = skc.KMeans(n_clusters=n_clusters)
km.fit(df_clustering.values)
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=10, n_init=10,
#     n_jobs=1, precompute_distances='auto', random_state=None, tol=0.0001,
#     verbose=0)

# %% [markdown]
# #### Counting the number of players in every cluster

# %%
for cl_idx in range(10):
    print "Number of players in Cluster no. "+str(cl_idx)+":",\
                    sum(km.labels_ == cl_idx)
# Out:
# Number of players in Cluster no. 0: 121
# Number of players in Cluster no. 1: 649
# Number of players in Cluster no. 2: 38
# Number of players in Cluster no. 3: 6
# Number of players in Cluster no. 4: 137
# Number of players in Cluster no. 5: 86
# Number of players in Cluster no. 6: 153
# Number of players in Cluster no. 7: 413
# Number of players in Cluster no. 8: 1
# Number of players in Cluster no. 9: 59

# %%
plt.scatter(df_clustering['ngoals'],km.labels_)
# Out:
# /Users/ta24418/anaconda/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning:
#
# elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison

# %% [markdown]
# #### Visualizing results

# %%
results = pd.DataFrame([df_clustering.index,km.labels_,df_clustering.season_value,\
                       df_clustering.ngoals,df_clustering.nassists,\
                       df_clustering.ntiebreaker_goals, df_clustering.ntiebreaker_assists]).T
results.columns = ['Player','Cluster','Value','Goals','Assists','TGoals', 'TAssists']

# %%
results[results['Player'] == 'Gareth Bale']
# Out:
#           Player Cluster  Value Goals Assists TGoals TAssists
# 544  Gareth Bale       9  64.05    21       4     10        2

# %%
results[results['Cluster'] == 3]
# Out:
#                    Player Cluster    Value Goals Assists TGoals TAssists
# 314     Cristiano Ronaldo       3  85.8375    34      10     10        2
# 994        Marek HamÅ¡Ã­k       3  69.6625    11      14     10        5
# 1322   Robert Lewandowski       3    69.25    24       7      9        2
# 1334     Robin van Persie       3   98.125    26       9     11        6
# 1458     Stefan KieÃling       3  75.5875    25       8     12        2
# 1628  Zlatan IbrahimoviÄ       3  82.1675    30       8     11        3

# %%
grouped12 = results.groupby('Cluster')

# %%
results['Value'] = results['Value'].astype(float)
results[['Assists','Goals','TAssists','TGoals']] = results[['Assists','Goals','TAssists','TGoals']].astype(int)

# %%
grouped12.describe()
# Out:
#                   Assists       Goals    TAssists      TGoals       Value
# Cluster
# 0       count  121.000000  121.000000  121.000000  121.000000  121.000000
#         mean     4.066116    5.652893    1.917355    2.495868   24.613326
#         std      2.407404    2.851055    1.369834    1.522739    4.466548
#         min      0.000000    0.000000    0.000000    0.000000   17.500000
#         25%      2.000000    4.000000    1.000000    1.000000   21.462500
#         50%      4.000000    5.000000    2.000000    2.000000   23.825000
#         75%      6.000000    7.000000    3.000000    3.000000   26.862500
#         max     11.000000   15.000000    5.000000    7.000000   41.962500
# 1       count  649.000000  649.000000  649.000000  649.000000  649.000000
#         mean     0.719569    0.690293    0.238829    0.277350    3.295705
#         std      0.788577    0.723022    0.440926    0.478031    1.997379
#         min      0.000000    0.000000    0.000000    0.000000    0.000000
#         25%      0.000000    0.000000    0.000000    0.000000    2.500000
#         50%      1.000000    1.000000    0.000000    0.000000    3.000000
#         75%      1.000000    1.000000    0.000000    1.000000    4.025000
#         max      5.000000    4.000000    2.000000    2.000000   11.650000
# 2       count   38.000000   38.000000   38.000000   38.000000   38.000000
#         mean     6.289474   14.921053    2.894737    7.078947   52.372533
#         std      3.212374    4.873434    1.656918    2.744839    8.067239
#         min      0.000000    9.000000    0.000000    2.000000   40.762500
#         25%      4.000000   11.250000    2.000000    5.000000   46.476875
#         50%      6.000000   14.000000    3.000000    6.500000   52.537500
#         75%      9.000000   15.750000    4.000000    9.000000   56.856250
#         max     13.000000   29.000000    7.000000   14.000000   74.287500
# 3       count    6.000000    6.000000    6.000000    6.000000    6.000000
#         mean     9.333333   25.000000    3.333333   10.500000   80.105000
#         std      2.503331    7.797435    1.751190    1.048809   11.037396
#         min      7.000000   11.000000    2.000000    9.000000   69.250000
#         25%      8.000000   24.250000    2.000000   10.000000   71.143750
#         50%      8.500000   25.500000    2.500000   10.500000   78.877500
# ...                   ...         ...         ...         ...         ...
# 6       std      1.809632    1.714183    1.185278    0.931476    2.892336
#         min      0.000000    0.000000    0.000000    0.000000    7.750000
#         25%      1.000000    1.000000    0.000000    0.000000   11.662500
#         50%      2.000000    3.000000    1.000000    1.000000   13.650000
#         75%      4.000000    4.000000    2.000000    2.000000   15.525000
#         max      7.000000    8.000000    5.000000    3.000000   22.025000
# 7       count  413.000000  413.000000  413.000000  413.000000  413.000000
#         mean     1.447942    1.610169    0.673123    0.740920    8.112682
#         std      1.279156    1.170260    0.810836    0.808448    2.513236
#         min      0.000000    0.000000    0.000000    0.000000    3.862500
#         25%      0.000000    1.000000    0.000000    0.000000    6.162500
#         50%      1.000000    2.000000    0.000000    1.000000    7.750000
#         75%      2.000000    2.000000    1.000000    1.000000    9.600000
#         max      7.000000    6.000000    3.000000    4.000000   16.250000
# 8       count    1.000000    1.000000    1.000000    1.000000    1.000000
#         mean    12.000000   46.000000    5.000000   14.000000  128.208750
#         std           NaN         NaN         NaN         NaN         NaN
#         min     12.000000   46.000000    5.000000   14.000000  128.208750
#         25%     12.000000   46.000000    5.000000   14.000000  128.208750
#         50%     12.000000   46.000000    5.000000   14.000000  128.208750
#         75%     12.000000   46.000000    5.000000   14.000000  128.208750
#         max     12.000000   46.000000    5.000000   14.000000  128.208750
# 9       count   59.000000   59.000000   59.000000   59.000000   59.000000
#         mean     5.627119   11.610169    2.542373    5.084746   42.148930
#         std      4.008174    4.193661    2.168124    2.479489    5.753110
#         min      0.000000    3.000000    0.000000    0.000000   31.950000
#         25%      2.000000    9.000000    1.000000    3.000000   38.518750
#         50%      5.000000   11.000000    2.000000    5.000000   41.650000
#         75%      7.500000   13.500000    4.000000    6.000000   44.012500
#         max     16.000000   25.000000   10.000000   12.000000   64.050000
#
# [80 rows x 5 columns]

# %%
results.to_pickle('../Data/clusteredDF12-13.pkl')

# %%
colors = cm.rainbow(np.linspace(0, 1, n_clusters))

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax = Axes3D(fig)
cluster_idx = 0
for c in colors:
    ax.scatter(results['Value'][results['Cluster'] == cluster_idx],\
                results['Goals'][results['Cluster'] == cluster_idx],
            zs=results['Assists'][results['Cluster'] == cluster_idx],\
                color=c)
    cluster_idx += 1

# %%
cluster_idx = 0
for c in colors:
    plt.scatter(results['Value'][results['Cluster'] == cluster_idx],\
                results['Goals'][results['Cluster'] == cluster_idx],\
                color=c)
    cluster_idx += 1

# %%
# Dictionary of style options for all axes
axis = dict(
    showbackground=True, # (!) show axis background
    backgroundcolor="rgb(204, 204, 204)", # set background color to grey
    gridcolor="rgb(255, 255, 255)",       # set grid line color
    zerolinecolor="rgb(255, 255, 255)",   # set zero grid line color
)

# Make a layout object
layout = Layout(
    title='Cluster Distribution', # set plot title
    scene=Scene(  # (!) axes are part of a 'scene' in 3d plots
        xaxis=XAxis(axis,title='Assists'), # set x-axis style
        yaxis=YAxis(axis,title='Goals'), # set y-axis style
        zaxis=ZAxis(axis,title='Season Value')  # set z-axis style
    )
)

# %%
cluster_idx=0
trace_list = []
for c in range(n_clusters):
    trace = Scatter3d(
        z=np.array(results['Value'][results['Cluster'] == c].astype(float)),
        x=np.array(results['Assists'][results['Cluster'] == c].astype(float)),
        y=np.array(results['Goals'][results['Cluster'] == c].astype(float)),
        name = "Cluster" + str(c),
        text= results['Player'][results['Cluster'] == c].astype(unicode),
        mode='markers')
    trace_list.append(trace)
data = Data(trace_list)

# %%
# Make a figure object
fig = Figure(data=data, layout=layout)

# (@) Send to Plotly and show in notebook
py.iplot(fig, filename='s8_surface')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~AbhishekMalali/8.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# #### Analyzing data for 2013-14 Season

# %%
features13 = pd.read_pickle('../Data/features13-14.pkl')
tr_features13 = features13.transpose()
#Splitting the smoothed_value_list into 38 new columns
split_fn = lambda x: pd.Series([i for i in x])
tr_features13_sm = tr_features13['smoothed_value_list'].apply(split_fn)
#Splitting the cum_value_list into 38 new columns
tr_features13_cm = tr_features13['cum_value_list'].apply(split_fn)

# %%
#Generating column names for the new dataframe
col_names_sm = []
col_names_cm = []
for i in range(38):
    col_names_sm.append('smooth_value_week_'+str(i+1))
    col_names_cm.append('cuml_value_week_'+str(i+1))
#Setting the column names for the new dataframe
tr_features13_sm.columns = col_names_sm
tr_features13_cm.columns = col_names_cm

# %%
#Concatenating the two dataframes
df_features13 = pd.concat([tr_features13,tr_features13_sm,tr_features13_cm],axis=1)

# %%
#Selecting columns to be clustered
columns_cluster = [[u'avg_value'], [u'avg_value_smoothed'],
        [u'nassists'], [u'naway_assists'], [u'naway_goals'],
        [u'nearly_assists'], [u'nearly_goals'], [u'nequalizer_assists'],
        [u'nequalizer_goals'], [u'ngoals'], [u'nhome_assists'], [u'nhome_goals'],
        [u'nlate_assists'], [u'nlate_goals'], [u'nmid_assists'], [u'nmid_goals'],
        [u'nsub_assists'], [u'nsub_goals'], [u'ntiebreaker_assists'],
        [u'ntiebreaker_goals'], [u'season_value'],col_names_sm, col_names_cm]
columns_cluster = list(itertools.chain(*columns_cluster))
#Creating a new dataframe to be used for clustering
df_clustering = df_features13[columns_cluster]
df_clustering = df_clustering.dropna(axis=0)

# %%
df_clustering.head(5)
# Out:
#               avg_value avg_value_smoothed nassists naway_assists naway_goals  \
# Aaron Hughes          0                  0        0             0           0
# Aaron Hunt    0.8835526          0.8835526        7             4           3
# Aaron Lennon  0.1638158          0.1493421        4             2           0
# Aaron Ramsey  0.9121711          0.8631195        7             5           7
# AarÃ³n        0.1059211          0.1059211        1             1           1
#
#              nearly_assists nearly_goals nequalizer_assists nequalizer_goals  \
# Aaron Hughes              0            0                  0                0
# Aaron Hunt                2            0                  1                3
# Aaron Lennon              0            0                  0                0
# Aaron Ramsey              1            1                  0                0
# AarÃ³n                    0            0                  1                0
#
#              ngoals        ...         cuml_value_week_29 cuml_value_week_30  \
# Aaron Hughes      0        ...                     0.0000             0.0000
# Aaron Hunt        7        ...                    20.2125            20.2125
# Aaron Lennon      1        ...                     2.6125             2.6125
# Aaron Ramsey     10        ...                    26.9000            26.9000
# AarÃ³n            1        ...                     4.0250             4.0250
#
#              cuml_value_week_31 cuml_value_week_32 cuml_value_week_33  \
# Aaron Hughes             0.0000             0.0000             0.0000
# Aaron Hunt              22.9625            26.4125            30.4125
# Aaron Lennon             2.6125             2.6125             2.6125
# Aaron Ramsey            26.9000            26.9000            26.9000
# AarÃ³n                   4.0250             4.0250             4.0250
#
#              cuml_value_week_34 cuml_value_week_35 cuml_value_week_36  \
# Aaron Hughes              0.000             0.0000             0.0000
# Aaron Hunt               33.575            33.5750            33.5750
# Aaron Lennon              3.475             6.2250             6.2250
# Aaron Ramsey             26.900            31.2125            31.2125
# AarÃ³n                    4.025             4.0250             4.0250
#
#              cuml_value_week_37 cuml_value_week_38
# Aaron Hughes             0.0000             0.0000
# Aaron Hunt              33.5750            33.5750
# Aaron Lennon             6.2250             6.2250
# Aaron Ramsey            31.2125            34.6625
# AarÃ³n                   4.0250             4.0250
#
# [5 rows x 97 columns]

# %% [markdown]
# #### Clustering using K-Means

# %%
n_clusters = 10
km = skc.KMeans(n_clusters=n_clusters)
km.fit(df_clustering.values)
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=10, n_init=10,
#     n_jobs=1, precompute_distances='auto', random_state=None, tol=0.0001,
#     verbose=0)

# %% [markdown]
# #### Counting the number of players in every cluster

# %%
for cl_idx in range(10):
    print "Number of players in Cluster no. "+str(cl_idx)+":",\
                    sum(km.labels_ == cl_idx)
# Out:
# Number of players in Cluster no. 0: 165
# Number of players in Cluster no. 1: 55
# Number of players in Cluster no. 2: 404
# Number of players in Cluster no. 3: 74
# Number of players in Cluster no. 4: 50
# Number of players in Cluster no. 5: 20
# Number of players in Cluster no. 6: 457
# Number of players in Cluster no. 7: 166
# Number of players in Cluster no. 8: 73
# Number of players in Cluster no. 9: 178

# %%
results = pd.DataFrame([df_clustering.index,km.labels_,df_clustering.season_value,\
                       df_clustering.ngoals,df_clustering.nassists,\
                       df_clustering.ntiebreaker_goals, df_clustering.ntiebreaker_assists]).T
results.columns = ['Player','Cluster','Value','Goals','Assists','TGoals', 'TAssists']

# %%
results[results['Player'] == 'Gareth Bale']
# Out:
#           Player Cluster    Value Goals Assists TGoals TAssists
# 525  Gareth Bale       1  46.2475    15      12      4        3

# %%
results[results['Cluster'] == 4]
# Out:
#                     Player Cluster    Value Goals Assists TGoals TAssists
# 1               Aaron Hunt       4   33.575     7       7      2        4
# 15            Adam Johnson       4    29.65     8       6      3        1
# 42        Alberto Paloschi       4  38.7375    13       1      6        1
# 70         Alexander Meier       4  28.2625     8       2      3        2
# 120      Antonio Di Natale       4     44.8    16       1      8        1
# 159        Bafetimbi Gomis       4     31.9    14       1      5        0
# 165                 Barral       4  23.3625     7       0      4        0
# 177        Benjamin AndrÃ©       4  26.9375     4       5      3        3
# 261      Christian Eriksen       4   38.675     7       9      2        6
# 283        Claudio Pizarro       4   38.335    10       3      3        1
# 296               Coutinho       4  28.2625     5       7      3        3
# 352          Danny Welbeck       4   24.125     9       2      3        0
# 398       Dimitar Berbatov       4  30.2875    10       3      5        2
# 399          Dimitri Payet       4   29.025     8       4      4        2
# 413          Dries Mertens       4  37.9625    11       5      6        2
# 444      Emmanuel Adebayor       4   36.425    11       4      5        3
# 568      Gonzalo Bergessio       4     30.9     9       1      6        1
# 584       GrÃ©gory SertiÄ       4     34.3     3       9      2        7
# 610               Hernanes       4   27.725     5       4      3        3
# 650         Ivan PeriÅ¡iÄ       4  31.5875    10       4      5        2
# 705       JesÃ© RodrÃ­guez       4   28.025     5       4      3        1
# 710           Jimmy Briand       4   30.775     6       5      1        0
# 711       Joaquin Larrivey       4  30.7375    12       3      3        0
# 765                 Joselu       4  25.0625     9       2      4        0
# 782          Juan Cuadrado       4    38.75    11       5      5        2
# 802                JussiÃª       4  26.9625     9       1      5        1
# 803   JÃ©rÃ©mie AliadiÃ©re       4  34.8625     8       3      7        1
# 837            Kevin Nolan       4   27.425     7       5      3        3
# 845    Klaas Jan Huntelaar       4  27.4125    12       0      5        0
# 865         Layvin Kurzawa       4  27.5875     5       3      3        2
# 911                  Lucas       4  29.4375     5       9      2        3
# 1000         Martin Harnik       4    27.75    10       2      5        0
# 1036         Mattia Destro       4    31.55    13       1      7        1
# 1047          Mauro Icardi       4  40.1625     9       2      8        1
# 1065       MevlÃ¼t ErdinÃ§       4     32.4    12       1      5        1
# 1092        Miroslav Klose       4  27.6375     7       3      5        1
# 1143        Nicola Sansone       4  32.5875     7       6      3        2
# 1165                Nolito       4   40.925    14       2      5        2
# 1172         OdaÃ¯r Fortes       4  25.0625     4       3      2        2
# 1186           Oriol Riera       4     30.1    13       0      6        0
# 1210                Parejo       4  31.8375     4       6      3        3
# 1214      Patrick Herrmann       4    30.45     6       9      3        4
# 1240          Peter Crouch       4  31.9625     7       5      4        2
# 1334   Romain Alessandrini       4     26.4     6       5      2        2
# 1374          Samuel Eto'o       4  29.8625     9       4      7        0
# 1404          Serge Aurier       4  27.8625     6       6      2        2
# 1432     Sofiane FÃ©ghouli       4  28.3125     4       8      0        4
# 1568          Waris Majeed       4    34.45     9       2      7        1
# 1584       Xherdan Shaqiri       4   24.575     6       2      2        1
# 1626      Ãngel Di MarÃ­a       4  44.4375     4      17      3        6

# %%
results.to_pickle('../Data/clusteredDF13-14.pkl')
